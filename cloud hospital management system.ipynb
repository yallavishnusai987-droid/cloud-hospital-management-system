# %%
patients = {}

def add_patient():
    patient_id = input("Enter Patient ID: ")

    if patient_id in patients:
        print("Patient ID already exists!")
        return

    name = input("Enter Patient Name: ")
    age = input("Enter Age: ")
    gender = input("Enter Gender: ")
    disease = input("Enter Disease: ")
    doctor = input("Enter Doctor Name: ")

    patients[patient_id] = {
        "Name": name,
        "Age": age,
        "Gender": gender,
        "Disease": disease,
        "Doctor": doctor
    }

    print("Patient added successfully!")

def view_patients():
    if not patients:
        print("No patient records found.")
        return

    print("\n------ Patient Records ------")

    for pid, details in patients.items():
        print("\nPatient ID:", pid)
        for key, value in details.items():
            print(f"{key}: {value}")

def search_patient():
    patient_id = input("Enter Patient ID to search: ")

    if patient_id in patients:
        print("\nPatient Details")
        for key, value in patients[patient_id].items():
            print(f"{key}: {value}")
    else:
        print("Patient not found.")

def update_patient():
    patient_id = input("Enter Patient ID to update: ")

    if patient_id in patients:
        print("Enter new details")

        patients[patient_id]["Name"] = input("Name: ")
        patients[patient_id]["Age"] = input("Age: ")
        patients[patient_id]["Gender"] = input("Gender: ")
        patients[patient_id]["Disease"] = input("Disease: ")
        patients[patient_id]["Doctor"] = input("Doctor: ")

        print("Patient updated successfully!")
    else:
        print("Patient not found.")

def delete_patient():
    patient_id = input("Enter Patient ID to delete: ")

    if patient_id in patients:
        del patients[patient_id]
        print("Patient deleted successfully!")
    else:
        print("Patient not found.")

while True:
    print("\n===================================")
    print(" Cloud Hospital Management System")
    print("===================================")
    print("1. Add Patient")
    print("2. View Patients")
    print("3. Search Patient")
    print("4. Update Patient")
    print("5. Delete Patient")
    print("6. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_patient()

    elif choice == "2":
        view_patients()

    elif choice == "3":
        search_patient()

    elif choice == "4":
        update_patient()

    elif choice == "5":
        delete_patient()

    elif choice == "6":
        print("Thank you for using Cloud Hospital Management System.")
        break

    else:
        print("Invalid choice! Please try again.")
# Out:
# ...
#  Cloud Hospital Management System
# ...
# 1. Add Patient
# 2. View Patients
# 3. Search Patient
# 4. Update Patient
# 5. Delete Patient
# 6. Exit
# Enter your choice: 1
# Enter Patient ID: p101
# Enter Patient Name: sai
# Enter Age: 20
# Enter Gender: male
# Enter Disease: fever
# Enter Doctor Name: vishnu
# Patient added successfully!
#
# ...
#  Cloud Hospital Management System
# ...
# 1. Add Patient
# 2. View Patients
# 3. Search Patient
# 4. Update Patient
# 5. Delete Patient
# 6. Exit
